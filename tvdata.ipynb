# %% [markdown]
# <a href="https://colab.research.google.com/github/BE-FARAD/tvdatafeed/blob/main/tvdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --no-cache-dir git+https://github.com/StreamAlpha/tvdatafeed.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/StreamAlpha/tvdatafeed.git to /tmp/pip-req-build-ppve81u5
#   Running command git clone --filter=blob:none --quiet https://github.com/StreamAlpha/tvdatafeed.git /tmp/pip-req-build-ppve81u5
#   Resolved https://github.com/StreamAlpha/tvdatafeed.git to commit a7034f04509b67224618917c29272796e4fff858
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=7566 sha256=eba2f288e0e400c20d06d2e75a761e13b3dea26aa3f462dc73075c441615dff6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aiagrgwf/wheels/a4/80/7a/04bbe70838a72f13c4511eb1b4baf894bf0b3a559ca4287aa5
# Successfully built tvdatafeed
# ...

# %%
from tvDatafeed import TvDatafeed, Interval

username = 'Alami-'
password = 'Ey1oba1Casa'

tv = TvDatafeed(username, password)

# %%
tv = TvDatafeed()
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
# index
nifty_index_data = tv.get_hist(symbol='NIFTY',exchange='NSE',interval=Interval.in_1_hour,n_bars=1000)

nifty_index_data
# Out:
#                         symbol      open      high       low     close  \
# datetime
# 2022-08-17 06:45:00  NSE:NIFTY  17930.15  17945.10  17922.25  17934.80
# 2022-08-17 07:45:00  NSE:NIFTY  17934.20  17943.90  17917.10  17924.05
# 2022-08-17 08:45:00  NSE:NIFTY  17923.85  17965.95  17916.40  17946.15
# 2022-08-17 09:45:00  NSE:NIFTY  17946.65  17946.65  17927.40  17929.05
# 2022-08-18 03:45:00  NSE:NIFTY  17916.05  17954.65  17863.45  17940.40
# ...                        ...       ...       ...       ...       ...
# 2023-03-14 05:45:00  NSE:NIFTY  17055.25  17088.90  17038.55  17069.20
# 2023-03-14 06:45:00  NSE:NIFTY  17068.90  17185.70  17026.20  17036.50
# 2023-03-14 07:45:00  NSE:NIFTY  17034.80  17064.15  16998.70  17008.70
# 2023-03-14 08:45:00  NSE:NIFTY  17009.50  17075.95  16987.10  17059.45
# 2023-03-14 09:45:00  NSE:NIFTY  17060.00  17068.65  17037.80  17068.65
#
#                          volume
# datetime
# 2022-08-17 06:45:00  27599895.0
# ...
